# %% [markdown]
# Small notebook to grab some philly crime data, philly weather data, and philly income data, clean it, and convert to csv.

# %% [markdown]
# # Installing and importing libraries

# %%
# Install necessary libs
# !pip install beautifulsoup4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import date, timedelta

# %% [markdown]
# #Grabbing Philadelphia Crime Data for 2025 and 2024.
#
# **Download links follow the scheme:**
#
# https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%27\<**BEGINNING YEAR**\>-01-01%27%20AND%20dispatch_date_time%20%3C%20%27\<**YEAR AFTER**\>-01-01%27

# %%
base_url = 'https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%27'
mid_url = '-01-01%27%20AND%20dispatch_date_time%20%3C%20%27'
end_url = '-01-01%27'

for year in range(2024, 2026):
  full_url = '\'' + base_url + str(year) + mid_url + str(year+1) + end_url + '\''
  output_fname = '\'' + 'ExampleData/' + str(year) + 'PhillyCrimeData.csv\''
  # print(output_fname)
  # !wget $full_url -O $output_fname
# Out:
# --2025-06-08 13:57:42--  https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%272024-01-01%27%20AND%20dispatch_date_time%20%3C%20%272025-01-01%27
# Resolving phl.carto.com (phl.carto.com)... 35.222.16.111
# Connecting to phl.carto.com (phl.carto.com)|35.222.16.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘ExampleData/2024PhillyCrimeData.csv’
#
# ExampleData/2024Phi     [         <=>        ]  42.77M  26.1MB/s    in 1.6s
#
# 2025-06-08 13:57:49 (26.1 MB/s) - ‘ExampleData/2024PhillyCrimeData.csv’ saved [44852385]
#
# ...

# %%
crime2025 = pd.read_csv('ExampleData/2025PhillyCrimeData.csv')
crime2025.info()
crime2025.head(100)

crime2024 = pd.read_csv('ExampleData/2024PhillyCrimeData.csv')
crime2024.info()
crime2024.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61894 entries, 0 to 61893
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   the_geom              60494 non-null  object
#  1   cartodb_id            61894 non-null  int64
#  2   the_geom_webmercator  60494 non-null  object
#  3   objectid              61894 non-null  int64
#  4   dc_dist               61894 non-null  int64
#  5   psa                   61883 non-null  object
#  6   dispatch_date_time    61894 non-null  object
#  7   dispatch_date         61894 non-null  object
#  8   dispatch_time         61894 non-null  object
#  9   hour                  61894 non-null  int64
#  10  dc_key                61894 non-null  float64
#  11  location_block        61894 non-null  object
#  12  ucr_general           61894 non-null  int64
#  13  text_general_code     61894 non-null  object
#  14  point_x               60496 non-null  float64
# ...

# %%
crime2024[crime2024['hour'].isna()]
# Out:
# Empty DataFrame
# Columns: [the_geom, cartodb_id, the_geom_webmercator, objectid, dc_dist, psa, dispatch_date_time, dispatch_date, dispatch_time, hour, dc_key, location_block, ucr_general, text_general_code, point_x, point_y, lat, lng]
# Index: []

# %% [markdown]
# # Grabbing Philly Crime 2016

# %%
base_url = "https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&skipfields=cartodb_id,the_geom,the_geom_webmercator&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%27"
mid_url = '-01-01%27%20AND%20dispatch_date_time%20%3C%20%27'
end_url = '-01-01%27'

for year in range(2016, 2017):
  full_url = '\'' + base_url + str(year) + mid_url + str(year+1) + end_url + '\''
  output_fname = '\'' + 'ExampleData/' + str(year) + 'PhillyCrimeData.csv\''
  print(full_url)
  # !wget $full_url -O $output_fname
# Out:
# 'https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&skipfields=cartodb_id,the_geom,the_geom_webmercator&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%272016-01-01%27%20AND%20dispatch_date_time%20%3C%20%272017-01-01%27'
# --2025-06-08 13:57:54--  https://phl.carto.com/api/v2/sql?filename=incidents_part1_part2&format=csv&skipfields=cartodb_id,the_geom,the_geom_webmercator&q=SELECT%20*%20,%20ST_Y(the_geom)%20AS%20lat,%20ST_X(the_geom)%20AS%20lng%20FROM%20incidents_part1_part2%20WHERE%20dispatch_date_time%20%3E=%20%272016-01-01%27%20AND%20dispatch_date_time%20%3C%20%272017-01-01%27
# Resolving phl.carto.com (phl.carto.com)... 35.222.16.111
# Connecting to phl.carto.com (phl.carto.com)|35.222.16.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘ExampleData/2016PhillyCrimeData.csv’
#
# ...

# %%
crime2016 = pd.read_csv('ExampleData/2016PhillyCrimeData.csv')
crime2016.info()
crime2016.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161321 entries, 0 to 161320
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   objectid            161321 non-null  int64
#  1   dc_dist             161321 non-null  int64
#  2   psa                 161278 non-null  object
#  3   dispatch_date_time  161321 non-null  object
#  4   dispatch_date       161321 non-null  object
#  5   dispatch_time       161321 non-null  object
#  6   hour                161316 non-null  float64
#  7   dc_key              161321 non-null  float64
#  8   location_block      161321 non-null  object
#  9   ucr_general         161321 non-null  int64
#  10  text_general_code   161321 non-null  object
#  11  point_x             159584 non-null  float64
#  12  point_y             159584 non-null  float64
#  13  lat                 159584 non-null  float64
#  14  lng                 159584 non-null  float64
# ...

# %% [markdown]
# # Figuring Out Schema of Crime Data

# %%
print(list(crime2024.columns))
print(crime2024.info())
crime2024.head()
# Out:
# ['the_geom', 'cartodb_id', 'the_geom_webmercator', 'objectid', 'dc_dist', 'psa', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat', 'lng']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160388 entries, 0 to 160387
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   the_geom              153713 non-null  object
#  1   cartodb_id            160388 non-null  int64
#  2   the_geom_webmercator  153644 non-null  object
#  3   objectid              160388 non-null  int64
#  4   dc_dist               160388 non-null  int64
#  5   psa                   160337 non-null  object
#  6   dispatch_date_time    160388 non-null  object
#  7   dispatch_date         160388 non-null  object
#  8   dispatch_time         160388 non-null  object
#  9   hour                  160388 non-null  int64
# ...

# %% [markdown]
# ## Cols to keep
# All Columns:
# ['the_geom', 'cartodb_id', 'the_geom_webmercator', 'objectid', 'dc_dist', 'psa', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat', 'lng']
#
# Cols to keep:
# ['objectid', 'dc_dist', 'dispatch_date', 'hour', 'location_block', 'text_general_code', 'lat', 'lng']
#
# objectid: unique id for the row
#
# dc_dist: police district

# %%
keep_cols = ['objectid', 'dc_dist', 'dispatch_date', 'hour', 'location_block', 'text_general_code', 'ucr_general', 'lat', 'lng']

crime2024 = crime2024[keep_cols]
crime2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160388 entries, 0 to 160387
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   objectid           160388 non-null  int64
#  1   dc_dist            160388 non-null  int64
#  2   dispatch_date      160388 non-null  datetime64[ns]
#  3   hour               160388 non-null  int64
#  4   location_block     160366 non-null  object
#  5   text_general_code  160388 non-null  object
#  6   ucr_general        160388 non-null  int64
#  7   lat                153644 non-null  float64
#  8   lng                153644 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 11.0+ MB

# %% [markdown]
# ## Cleaning
# 1. Will want to get rid of rows that have null lat, lng, psa, hour, and location block
# 2. Figure out the text_general_code types
# 3. Figure out Location Block Types --> Theres too many
# 4. Convert dispatch_date to date type
# 5. Convert hour to INTEGER

# %%
crime2024['hour'].value_counts()
crime2024['location_block'].value_counts()
# Out:
# location_block
# 5500 BLOCK TULIP ST            551
# 2100 BLOCK SOUTH ST            493
# 100 BLOCK W CHELTEN AV         485
# 6500 BLOCK FRANKFORD AV        421
# 7900 BLOCK E ROOSEVELT BLVD    386
#                               ...
# 500 BLOCK S JUNIPER ST           1
# 7000 BLOCK WISSAHICKON AV        1
# 2700 BLOCK W ARIZONA ST          1
# 5300 BLOCK PASCHALL AV           1
# 76th& Ogontz Av                  1
# Name: count, Length: 33253, dtype: int64

# %%
crime2024['dispatch_date'] = pd.to_datetime(crime2024['dispatch_date'])
crime2024['hour'] = crime2024['hour'].fillna(0)
crime2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160388 entries, 0 to 160387
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   objectid           160388 non-null  int64
#  1   dc_dist            160388 non-null  int64
#  2   dispatch_date      160388 non-null  datetime64[ns]
#  3   hour               160388 non-null  int64
#  4   location_block     160366 non-null  object
#  5   text_general_code  160388 non-null  object
#  6   ucr_general        160388 non-null  int64
#  7   lat                153644 non-null  float64
#  8   lng                153644 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 11.0+ MB
# /var/folders/q5/w3l78p3150v1ngzj8475_6th0000gn/T/ipykernel_85804/3295085678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/test')
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
# we can now use our engine to get the specific output for Postgres
print(pd.io.sql.get_schema(crime2024, name='crime2024', con=engine))

# %% [markdown]
# ## Schema gor Google Cloud
# CREATE TABLE crime2024 (
#     unique_row_id BYTES,
#     filename STRING,
# 	objectid INTEGER,
# 	dc_dist INTEGER,
# 	dispatch_date TIMESTAMP,
# 	hour INTEGER,
# 	location_block STRING,
# 	text_general_code STRING,
# 	lat NUMERIC,
# 	lng NUMERIC
# )

# %% [markdown]
# # Grabbing Philly Park Data
# This is not needed because it is all contained in the playground dataset

# %%
URL = '\'https://opendata.arcgis.com/api/v3/datasets/9eb26a787a6e448ba426eea7f9f0d93a_0/downloads/data?format=csv&spatialRefId=4326\''
output_fname = 'ExampleData/PhillyPark.csv'

# !wget $URL -O $output_fname

# %%
phillypark = pd.read_csv('ExampleData/PhillyPark.csv')
phillypark.info()
phillypark.head(100)
len(phillypark['PARK_NAME'].isin(phillyplayground['PARK_NAME']))

# %% [markdown]
# # Grabbing Philly Playground Data

# %%
URL = '\'https://opendata.arcgis.com/datasets/899c807e205244278b3f39421be8489c_0.csv\''
output_fname = 'ExampleData/PhillyPlay.csv'

# !wget $URL -O $output_fname

# %%
phillyplayground = pd.read_csv('ExampleData/PhillyPlay.csv')
phillyplayground.info()
phillyplayground.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   X               464 non-null    float64
#  1   Y               464 non-null    float64
#  2   OBJECTID        464 non-null    int64
#  3   PARK_NAME       464 non-null    object
#  4   AGE_RANGE       464 non-null    object
#  5   DATE_INSTALLED  214 non-null    object
#  6   COMMENTS        462 non-null    object
#  7   DATA_SOURCE     464 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 29.1+ KB
#                X             Y  OBJECTID                           PARK_NAME  \
# 0  -8.368373e+06  4.871673e+06      2561                   Morton Playground
# 1  -8.354619e+06  4.874931e+06      2562         George C Pelbano Playground
# 2  -8.365130e+06  4.860908e+06      2563          Lawrence Street Playground
# ...

# %% [markdown]
# ## Schema for playground data

# %%
print(list(phillyplayground.columns))
print(phillyplayground.columns[phillyplayground.isna().any()].tolist())

# %% [markdown]
# ## Cols to keep
# All Columns:
# ['X', 'Y', 'OBJECTID', 'PARK_NAME', 'AGE_RANGE', 'DATE_INSTALLED', 'COMMENTS', 'DATA_SOURCE']
#
#
# Cols to keep:
# ['X', 'Y', 'OBJECTID', 'PARK_NAME', 'AGE_RANGE']

# %%
keep_cols = ['X', 'Y', 'OBJECTID', 'PARK_NAME', 'AGE_RANGE']

phillyplayground = phillyplayground[keep_cols]
phillyplayground.info()

# %% [markdown]
# # Grabbing Philly Weather Data for 2024 and 2025

# %%
# Set date range
sdate = pd.to_datetime('2006-01-01')
edate = date.today()
dates = pd.date_range(sdate,edate,freq='d')

# Get rid of dashes in the date
dates = dates.strftime('%Y%m%d')
len(dates)

# %% [markdown]
# Using weather API to get historical data
#
# Using wunderground created issues since its table is dynamically created using JS, and thus cant be accessed through DOM. And I didnt want to use selenium
#
# API Endpoint is: https://api.weather.com/v1/location/KPHL:9:US/observations/historical.json?apiKey=e1f10a1e78da46f5b10a1e78da96f525&units=e&startDate=\<date\>

# %%
import requests
from datetime import datetime


base_url = 'https://api.weather.com/v1/location/KPHL:9:US/observations/historical.json?apiKey=e1f10a1e78da46f5b10a1e78da96f525&units=e&startDate='
phl_weather = []

# Get the average temp for each date
for date in dates:
  full_url = base_url + date
  print(date)
  try:
      response = requests.get(full_url).json()['observations']
      total = 0
      num_obs = 0
      for obs in response:
        if obs['temp'] != None:
          total += obs['temp']
          num_obs += 1
      avg_temp = total / num_obs
      phl_weather.append([str(datetime.strptime(date, '%Y%m%d').date()), avg_temp])        
  except:
      pass
        
# Convert to a dataframe
cols = ['Date', 'Avg Temp']
phl_weather = pd.DataFrame(phl_weather, columns=cols)

# %%
# Testing geopy library 
# !pip install geopy
import geopy


def get_zipcode(df, geolocator, lat, long):
    location = geolocator.reverse((df[lat], df[long]))
    return location



geolocator = geopy.Nominatim(user_agent="me")
crime2025['zip'] = crime2025.apply(get_zipcode, axis=1, geolocator=geolocator, lat='lat', long='lng')
crime2025
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461 try:
# ...

# %%
import datetime
crime2024[pd.to_datetime(crime2024['dispatch_date']) >= pd.to_datetime(datetime.date.today() - timedelta(days=367))]
# Out:
#         objectid  dc_dist dispatch_date  hour              location_block  \
# 0       28268376       25    2024-09-04    18             3200 BLOCK D ST
# 1       28268381       25    2024-06-28    13       3400 BLOCK CRYSTAL ST
# 2       28268383       39    2024-10-10    21        3700 BLOCK N 15TH ST
# 3       28268387       24    2024-10-13     4    3900 BLOCK KENSINGTON AV
# 4       28268392       25    2024-12-24    22  400 BLOCK E ROOSEVELT BLVD
# ...          ...      ...           ...   ...                         ...
# 160373  24885094       19    2024-11-29    21         900 BLOCK N 64TH ST
# 160380  24707339        9    2024-12-31    14        1200 BLOCK Locust St
# 160381  25056403       25    2024-12-27    11    3400 BLOCK N MARSHALL ST
# 160383  24312159        7    2024-11-15    10          9300 BLOCK HOFF ST
# 160385  24250468       14    2024-12-22    16             76th& Ogontz Av
#
#                      text_general_code  ucr_general        lat        lng
# ...

# %% [markdown]
# # Scraping Median Income Data

# %%
import re
url = 'https://zipatlas.com/us/pa/philadelphia/zip-code-comparison/highest-median-household-income.htm'

philly_income = pd.read_html(url)[0]
philly_income = philly_income.drop(columns=['Unnamed: 0', 'vs State',
       'vs National'])
philly_income.head()

# convert currency to int
philly_income['Household Income'] = philly_income['Household Income'].replace('[\$,]', '', regex=True).astype(float)

# %%
philly_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Zip Code          47 non-null     int64
#  1   Household Income  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
import pandas as pd
import re
import requests
from datetime import date, timedelta,  datetime


url = 'https://api.weather.com/v1/location/KPHL:9:US/observations/historical.json?apiKey=e1f10a1e78da46f5b10a1e78da96f525&units=e&startDate=20250526'
phl_weather = []


# Get the average temp
response = requests.get(url).json()['observations']

total = 0
num_obs = 0
for obs in response:
  if obs['temp'] != None:
    total += obs['temp']
    num_obs += 1
avg_temp = total / num_obs

phl_weather.append([str(datetime.strptime('2025-05-26', '%Y-%m-%d').date()), avg_temp])

# Convert to a dataframe
cols = ['Date', 'avg_temp']
phl_weather = pd.DataFrame(phl_weather, columns=cols)

# Convert date to date type
phl_weather['Date'] = pd.to_datetime(phl_weather['Date'])
phl_weather
# Out:
#         Date   avg_temp
# 0 2025-05-26  63.842105

# %%
import pandas as pd
import re
import requests
from datetime import date, timedelta,  datetime

date = '20250526'

base_url = 'https://api.weather.com/v1/location/KPHL:9:US/observations/historical.json?apiKey=e1f10a1e78da46f5b10a1e78da96f525&units=e&startDate='
url = base_url + date
# Get the average temp
response = requests.get(url).json()['observations']
print(response)

total = 0
num_obs = 0
for obs in response:
  if obs['temp'] != None:
    total += obs['temp']
    num_obs += 1
avg_temp = total / num_obs

phl_weather.append([str(datetime.strptime(date, '%Y%m%d').date()), avg_temp])

# Convert to a dataframe
cols = ['Date', 'avg_temp']
phl_weather = pd.DataFrame(phl_weather, columns=cols)

# Convert date to date type
phl_weather['Date'] = pd.to_datetime(phl_weather['Date'])
phl_weather
# phl_weather.to_csv('{{render(vars.output_name)}}', index=False)
# Out:
# [{'key': 'KPHL', 'class': 'observation', 'expire_time_gmt': 1748242440, 'obs_id': 'KPHL', 'obs_name': 'Philadelphia', 'valid_time_gmt': 1748235240, 'day_ind': 'N', 'temp': 58, 'wx_icon': 33, 'icon_extd': 3300, 'wx_phrase': 'Fair', 'pressure_tend': None, 'pressure_desc': None, 'dewPt': 45, 'heat_index': 58, 'rh': 62, 'pressure': 30.16, 'vis': 10, 'wc': 58, 'wdir': 350, 'wdir_cardinal': 'N', 'gust': None, 'wspd': 5, 'max_temp': 71, 'min_temp': 52, 'precip_total': None, 'precip_hrly': 0, 'snow_hrly': None, 'uv_desc': 'Low', 'feels_like': 58, 'uv_index': 0, 'qualifier': None, 'qualifier_svrty': None, 'blunt_phrase': None, 'terse_phrase': None, 'clds': 'FEW', 'water_temp': None, 'primary_wave_period': None, 'primary_wave_height': None, 'primary_swell_period': None, 'primary_swell_height': None, 'primary_swell_direction': None, 'secondary_swell_period': None, 'secondary_swell_height': None, 'secondary_swell_direction': None}, {'key': 'KPHL', 'class': 'observation', 'expire_time_gmt': 17482
# ...

# %% [markdown]
# ## Looking at DBT

# %%
crime2024
# Out:
#         objectid  dc_dist dispatch_date  hour               location_block  \
# 0       28268376       25    2024-09-04    18              3200 BLOCK D ST
# 1       28268381       25    2024-06-28    13        3400 BLOCK CRYSTAL ST
# 2       28268383       39    2024-10-10    21         3700 BLOCK N 15TH ST
# 3       28268387       24    2024-10-13     4     3900 BLOCK KENSINGTON AV
# 4       28268392       25    2024-12-24    22   400 BLOCK E ROOSEVELT BLVD
# ...          ...      ...           ...   ...                          ...
# 160383  24312159        7    2024-11-15    10           9300 BLOCK HOFF ST
# 160384  16362093        2    2024-05-09    17  7900 BLOCK E ROOSEVELT BLVD
# 160385  24250468       14    2024-12-22    16              76th& Ogontz Av
# 160386  16362952        7    2024-05-16    10         8100 BLOCK CASTOR AV
# 160387  16327977        9    2024-05-13    12         1900 BLOCK WALNUT ST
#
#           text_general_code  ucr_general        lat        lng
# ...

# %%
crime2024[['lat', 'lng']].value_counts()
# Out:
# lat        lng
# 40.012238  -75.066939    430
# 39.883896  -75.230667    367
# 40.030069  -75.056023    316
# 40.055555  -75.049197    298
# 39.947373  -75.228878    291
#                         ...
# 39.979301  -75.145629      1
# 39.979297  -75.131735      1
# 39.979296  -75.161896      1
# 39.979295  -75.157769      1
# 42.224336  -80.502372      1
# Name: count, Length: 85871, dtype: int64

# %%
phillyplayground['AGE_RANGE'].unique()
# Out:
# array(['5_12_YEARS', 'UNKNOWN', '2_12_YEARS', '2_5_YEARS', ' '],
#       dtype=object)
